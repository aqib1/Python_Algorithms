# %%
import pandas as pd

nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba = nba.dropna(how="all")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["Salary"] = nba["Salary"].fillna(0)
# Out:
# /var/folders/vk/p6qvytc90z38qct0h2zh9y8c0000gn/T/ipykernel_62031/225025968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba["Salary"] = nba["Salary"].fillna(0)

# %%
print("Hello I am adisa")
# Out:
# Hello I am adisa

# %%
name = input("Tell me your name ? = ")
print(f"My name is {name}")
# Out:
# Tell me your name ? =  Adisa
# My name is Adisa

# %%
import pandas as pd
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba = nba.dropna(how="all")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["Salary"] = nba["Salary"].fillna(0)
# Out:
# /var/folders/vk/p6qvytc90z38qct0h2zh9y8c0000gn/T/ipykernel_62031/225025968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba["Salary"] = nba["Salary"].fillna(0)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    591 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 36.9+ KB

# %%
nba["Salary"] = nba["Salary"].astype(int)
nba
# Out:
# /var/folders/vk/p6qvytc90z38qct0h2zh9y8c0000gn/T/ipykernel_62031/3863988206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba["Salary"] = nba["Salary"].astype(int)
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 586       Michigan  27955357
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
#
# [591 rows x 7 columns]

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending=False)

# %%
nba
# Out:
#                  Name                   Team Position Height  Weight  \
# 175     Stephen Curry  Golden State Warriors        G    6-2   185.0
# 461      Kevin Durant           Phoenix Suns        F   6-10   240.0
# 261      LeBron James     Los Angeles Lakers        F    6-9   250.0
# 145      Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 436       Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# ..                ...                    ...      ...    ...     ...
# 64        James Nnaji      Charlotte Hornets        F   6-11   250.0
# 132    Christian Wood       Dallas Mavericks        F    6-9   214.0
# 126       Theo Pinson       Dallas Mavericks      G-F    6-7   212.0
# 125   Markieff Morris       Dallas Mavericks        F    6-9   245.0
# 123  Dereck Lively II       Dallas Mavericks        C    7-1   230.0
#
#                           College    Salary  Salary Rank
# 175                      Davidson  51915615          1.0
# 461                         Texas  47649433          2.0
# 261  St. Vincent-St. Mary HS (OH)  47607350          4.0
# 145                   Mega Basket  47607350          4.0
# 436                        Kansas  47607350          4.0
# ..                            ...       ...          ...
# 64                   FC Barcelona         0        540.0
# 132                          UNLV         0        540.0
# 126                North Carolina         0        540.0
# 125                        Kansas         0        540.0
# 123                          Duke         0        540.0
#
# [591 rows x 8 columns]

# %%
nba = nba.sort_values(by="Salary", ascending=False)

# %%
nba
# Out:
#                      Name                   Team Position Height  Weight  \
# 175         Stephen Curry  Golden State Warriors        G    6-2   185.0
# 461          Kevin Durant           Phoenix Suns        F   6-10   240.0
# 261          LeBron James     Los Angeles Lakers        F    6-9   250.0
# 436           Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 145          Nikola Jokic         Denver Nuggets        C   6-11   284.0
# ..                    ...                    ...      ...    ...     ...
# 274       Tarik Biberovic      Memphis Grizzlies        F    6-7   218.0
# 272          Santi Aldama      Memphis Grizzlies      F-C    7-0   215.0
# 203      Kevin Porter Jr.        Houston Rockets      G-F    6-4   203.0
# 204  Jermaine Samuels Jr.        Houston Rockets        F    6-7   230.0
# 123      Dereck Lively II       Dallas Mavericks        C    7-1   230.0
#
#                           College    Salary  Salary Rank
# 175                      Davidson  51915615          1.0
# 461                         Texas  47649433          2.0
# 261  St. Vincent-St. Mary HS (OH)  47607350          4.0
# 436                        Kansas  47607350          4.0
# 145                   Mega Basket  47607350          4.0
# ..                            ...       ...          ...
# 274                           NaN         0        540.0
# 272               Loyola-Maryland         0        540.0
# 203           Southern California         0        540.0
# 204                     Villanova         0        540.0
# 123                          Duke         0        540.0
#
# [591 rows x 8 columns]

# %%
nba.sort_values(by="Salary", ascending=True)
# Out:
#                  Name                   Team Position Height  Weight  \
# 123  Dereck Lively II       Dallas Mavericks        C    7-1   230.0
# 39        Nic Claxton          Brooklyn Nets        C   6-11   215.0
# 125   Markieff Morris       Dallas Mavericks        F    6-9   245.0
# 126       Theo Pinson       Dallas Mavericks      G-F    6-7   212.0
# 132    Christian Wood       Dallas Mavericks        F    6-9   214.0
# ..                ...                    ...      ...    ...     ...
# 145      Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 436       Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 261      LeBron James     Los Angeles Lakers        F    6-9   250.0
# 461      Kevin Durant           Phoenix Suns        F   6-10   240.0
# 175     Stephen Curry  Golden State Warriors        G    6-2   185.0
#
#                           College    Salary  Salary Rank
# 123                          Duke         0        540.0
# 39                        Georgia         0        540.0
# 125                        Kansas         0        540.0
# 126                North Carolina         0        540.0
# 132                          UNLV         0        540.0
# ..                            ...       ...          ...
# 145                   Mega Basket  47607350          4.0
# 436                        Kansas  47607350          4.0
# 261  St. Vincent-St. Mary HS (OH)  47607350          4.0
# 461                         Texas  47649433          2.0
# 175                      Davidson  51915615          1.0
#
# [591 rows x 8 columns]
